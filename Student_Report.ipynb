# %% [markdown]
# **Task Description **
#
# You are provided with a raw dataset that contains various data quality problems such as
# missing values, duplicates, inconsistent formats, and incorrect data types. Your task is to
# clean the dataset using Pandas and prepare it for further analysis.

# %% [markdown]
#  **Load the Dataset**
#
#    Import the dataset using Pandas

# %%
import pandas as pd
df =pd.read_csv("/content/students_data.csv")

# %% [markdown]
# Display the first few rows and understand the structure of the data

# %%
df.head()
# Out:
#    student_id         name   age  gender grade  math_score english_score  \
# 0         100   jane smith  16.0  female    11        75.0           NaN
# 1         101     John Doe  16.0    Male  10th        74.0            95
# 2         102     Chris P.   NaN    MALE    10         NaN       missing
# 3         103   jane smith  16.0  FEMALE    10         NaN       missing
# 4         104  Sara O'Neil  16.0    male    11         NaN            96
#
#    science_score enrolled_date            remarks
# 0             66    2022-06-10          excellent
# 1             94    10-06-2022               GOOD
# 2             69    06/12/2022  needs improvement
# 3             62    10-06-2022            average
# 4             64    2022-06-10               GOOD

# %% [markdown]
#  **Explore the Data**
#
#   Check the number of rows and columns.
#
#    Inspect column names and data types.
#
#   Generate basic summary statistics.

# %%
df.shape
# Out:
# (31, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     31 non-null     int64
#  1   name           31 non-null     object
#  2   age            28 non-null     float64
#  3   gender         31 non-null     object
#  4   grade          31 non-null     object
#  5   math_score     13 non-null     float64
#  6   english_score  23 non-null     object
#  7   science_score  31 non-null     int64
#  8   enrolled_date  31 non-null     object
#  9   remarks        31 non-null     object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.6+ KB

# %%
df.describe()
# Out:
#        student_id        age  math_score  science_score
# count   31.000000  28.000000   13.000000      31.000000
# mean   114.967742  16.785714   74.000000      79.903226
# std      9.038746   0.629941   11.510864      13.095431
# min    100.000000  16.000000   64.000000      62.000000
# 25%    107.500000  16.000000   65.000000      66.500000
# 50%    115.000000  17.000000   73.000000      83.000000
# 75%    122.500000  17.000000   75.000000      90.500000
# max    129.000000  18.000000  100.000000     100.000000

# %% [markdown]
# **Handle Missing Values**
#
# Identify missing or null values in the dataset.
# Decide whether to:
#
#   Remove rows/columns with missing values, or
#   Fill missing values using appropriate methods (mean, median, mode, or constant
# values).
#
#
#  Justify your choice.

# %%
df.isnull().sum()
# Out:
# student_id        0
# name              0
# age               3
# gender            0
# grade             0
# math_score       18
# english_score     8
# science_score     0
# enrolled_date     0
# remarks           0
# dtype: int64

# %%
# Fill numerical columns with mean
df['age'] = df['age'].fillna(df['age'].mean())

# Fill categorical columns with mode
df['gender'] = df['gender'].fillna(df['gender'].mode()[0])
df
# Out:
#     student_id           name        age  gender grade  math_score  \
# 0          100     jane smith  16.000000  female    11        75.0
# 1          101       John Doe  16.000000    Male  10th        74.0
# 2          102       Chris P.  16.785714    MALE    10         NaN
# 3          103     jane smith  16.000000  FEMALE    10         NaN
# 4          104    Sara O'Neil  16.000000    male    11         NaN
# 5          105  Mike O’Reilly  16.000000  Female    10         NaN
# 6          106       ali Khan  17.000000  female    11        64.0
# 7          107    Sara O'Neil  17.000000  female    12         NaN
# 8          108  Mike O’Reilly  16.000000  Female    12        80.0
# 9          109   Robert Brown  17.000000  female    12         NaN
# 10         110      lucy gray  17.000000    male  11th        65.0
# 11         111   Simran Singh  16.000000  FEMALE  11th         NaN
# 12         112       Patel R.  17.000000  female    11         NaN
# 13         113       Patel R.  17.000000    male    10         NaN
# 14         114       Ali Khan  17.000000    male    12         NaN
# 15         115      Lucy gray  16.000000  Female    12        65.0
# 16         116       Chris P.  16.785714  Female    11         NaN
# 17         117       Ali Khan  18.000000    male  11th        67.0
# 18         118   Simran Singh  17.000000    Male    10       100.0
# 19         119       Patel R.  17.000000    MALE  11th        73.0
# 20         120    Sara O'Neil  17.000000    Male    10         NaN
# 21         121       John Doe  18.000000  female    11        66.0
# 22         122    Sara O'Neil  17.000000    MALE  11th        75.0
# 23         123     jane smith  17.000000  Female  11th         NaN
# 24         124       John Doe  18.000000    MALE  11th         NaN
# 25         125  Mike O’Reilly  17.000000    Male    12        94.0
# 26         126       John Doe  16.785714    Male  10th        64.0
# 27         127   Simran Singh  16.000000  FEMALE    12         NaN
# 28         128    Sara O'Neil  17.000000  female    11         NaN
# 29         129       Patel R.  17.000000    male    11         NaN
# 30         129       Patel R.  17.000000    male    11         NaN
#
#    english_score  science_score enrolled_date            remarks
# 0            NaN             66    2022-06-10          excellent
# 1             95             94    10-06-2022               GOOD
# 2        missing             69    06/12/2022  needs improvement
# 3        missing             62    10-06-2022            average
# 4             96             64    2022-06-10               GOOD
# 5            NaN             83    06/12/2022  needs improvement
# 6            NaN             75    06/12/2022               Good
# 7             63             62    2022/06/11          excellent
# 8        missing             89    06/12/2022               poor
# 9        missing             97    10-06-2022  needs improvement
# 10            67            100    06/12/2022          excellent
# 11       missing             95    2022-06-10            average
# 12            87             89    2022-06-10               poor
# 13           NaN             98    06/12/2022            Average
# 14            91             67    2022/06/11               poor
# 15            91             94    06/12/2022            Average
# 16           NaN             72    2022/06/11          excellent
# 17            74             81    2022-06-10               GOOD
# 18            74             62    2022/06/11            average
# 19           NaN             90    06/12/2022               Good
# 20       missing             89    2022-06-10            average
# 21            72             94    10-06-2022            Average
# 22           NaN             66    2022-06-10       good student
# 23       missing             63    06/12/2022          excellent
# 24           NaN             91    06/12/2022               GOOD
# 25            80             63    10-06-2022            Average
# 26       missing             67    06/12/2022       good student
# 27            76             80    06/12/2022               poor
# 28            64             89    2022-06-10            average
# 29            64             83    2022/06/11            Average
# 30            64             83    2022/06/11            Average

# %% [markdown]
# Justification
#
# Mean/median maintains numerical distribution.
#
# Mode preserves the most common category.
#
# Prevents unnecessary data loss

# %% [markdown]
#  **Remove Duplicate Records**
#
#  Detects duplicate rows in the dataset.
#
#  Remove duplicates and explain how many rows were affected.

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
initial_rows = df.shape[0]
df = df.drop_duplicates()
final_rows = df.shape[0]

print("Removed rows:", initial_rows - final_rows)
# Out:
# Removed rows: 1

# %% [markdown]
# **Fix Data Types**
#
#   Identify columns with incorrect data types (e.g., numbers stored as strings, dates
# as text).
#
#    Convert them to appropriate data types.

# %%
df.dtypes
# Out:
# student_id         int64
# name              object
# age              float64
# gender            object
# grade             object
# math_score       float64
# english_score     object
# science_score      int64
# enrolled_date     object
# remarks           object
# dtype: object

# %%
# Convert age to integer
df['age'] = df['age'].astype(int)

# Convert date column with mixed formats, prioritizing day-first interpretation
df['enrolled_date'] = pd.to_datetime(df['enrolled_date'], format='mixed', dayfirst=True)
df
# Out:
# /tmp/ipython-input-3449050.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df['age'].astype(int)
# /tmp/ipython-input-3449050.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['enrolled_date'] = pd.to_datetime(df['enrolled_date'], format='mixed', dayfirst=True)
#     student_id           name  age  gender grade  math_score english_score  \
# 0          100     jane smith   16  female    11        75.0           NaN
# 1          101       John Doe   16    Male  10th        74.0            95
# 2          102       Chris P.   16    MALE    10         NaN       missing
# 3          103     jane smith   16  FEMALE    10         NaN       missing
# 4          104    Sara O'Neil   16    male    11         NaN            96
# 5          105  Mike O’Reilly   16  Female    10         NaN           NaN
# 6          106       ali Khan   17  female    11        64.0           NaN
# 7          107    Sara O'Neil   17  female    12         NaN            63
# 8          108  Mike O’Reilly   16  Female    12        80.0       missing
# 9          109   Robert Brown   17  female    12         NaN       missing
# 10         110      lucy gray   17    male  11th        65.0            67
# 11         111   Simran Singh   16  FEMALE  11th         NaN       missing
# 12         112       Patel R.   17  female    11         NaN            87
# 13         113       Patel R.   17    male    10         NaN           NaN
# 14         114       Ali Khan   17    male    12         NaN            91
# 15         115      Lucy gray   16  Female    12        65.0            91
# 16         116       Chris P.   16  Female    11         NaN           NaN
# 17         117       Ali Khan   18    male  11th        67.0            74
# 18         118   Simran Singh   17    Male    10       100.0            74
# 19         119       Patel R.   17    MALE  11th        73.0           NaN
# 20         120    Sara O'Neil   17    Male    10         NaN       missing
# 21         121       John Doe   18  female    11        66.0            72
# 22         122    Sara O'Neil   17    MALE  11th        75.0           NaN
# 23         123     jane smith   17  Female  11th         NaN       missing
# 24         124       John Doe   18    MALE  11th         NaN           NaN
# 25         125  Mike O’Reilly   17    Male    12        94.0            80
# 26         126       John Doe   16    Male  10th        64.0       missing
# 27         127   Simran Singh   16  FEMALE    12         NaN            76
# 28         128    Sara O'Neil   17  female    11         NaN            64
# 29         129       Patel R.   17    male    11         NaN            64
#
#     science_score enrolled_date            remarks
# 0              66    2022-06-10          excellent
# 1              94    2022-06-10               GOOD
# 2              69    2022-12-06  needs improvement
# 3              62    2022-06-10            average
# 4              64    2022-06-10               GOOD
# 5              83    2022-12-06  needs improvement
# 6              75    2022-12-06               Good
# 7              62    2022-06-11          excellent
# 8              89    2022-12-06               poor
# 9              97    2022-06-10  needs improvement
# 10            100    2022-12-06          excellent
# 11             95    2022-06-10            average
# 12             89    2022-06-10               poor
# 13             98    2022-12-06            Average
# 14             67    2022-06-11               poor
# 15             94    2022-12-06            Average
# 16             72    2022-06-11          excellent
# 17             81    2022-06-10               GOOD
# 18             62    2022-06-11            average
# 19             90    2022-12-06               Good
# 20             89    2022-06-10            average
# 21             94    2022-06-10            Average
# 22             66    2022-06-10       good student
# 23             63    2022-12-06          excellent
# 24             91    2022-12-06               GOOD
# 25             63    2022-06-10            Average
# 26             67    2022-12-06       good student
# 27             80    2022-12-06               poor
# 28             89    2022-06-10            average
# 29             83    2022-06-11            Average

# %%
df.loc[:, 'age'] = df['age'].astype(int)

df.loc[:, 'enrolled_date'] = pd.to_datetime(
    df['enrolled_date'],
    format='mixed',
    dayfirst=True
)
df.dtypes
# Out:
# student_id                int64
# name                     object
# age                       int64
# gender                   object
# grade                    object
# math_score              float64
# english_score            object
# science_score             int64
# enrolled_date    datetime64[ns]
# remarks                  object
# dtype: object

# %% [markdown]
#  **Standardize and Clean Text Data**
#
# Clean text columns by:
#
#  Removing extra spaces
#
#   Converting text to lowercase or uppercase
#
#   Fixing inconsistent category names (e.g., “Male”, “male”, “M”)

# %%
df.loc[:, 'gender'] = df['gender'].str.strip()
df.loc[:, 'gender'] = df['gender'].str.lower()
df.loc[:, 'gender'] = df['gender'].replace({
    'm': 'male',
    'f': 'female'
})
df
# Out:
#     student_id           name  age  gender grade  math_score english_score  \
# 0          100     jane smith   16  female    11        75.0           NaN
# 1          101       John Doe   16    male  10th        74.0            95
# 2          102       Chris P.   16    male    10         NaN       missing
# 3          103     jane smith   16  female    10         NaN       missing
# 4          104    Sara O'Neil   16    male    11         NaN            96
# 5          105  Mike O’Reilly   16  female    10         NaN           NaN
# 6          106       ali Khan   17  female    11        64.0           NaN
# 7          107    Sara O'Neil   17  female    12         NaN            63
# 8          108  Mike O’Reilly   16  female    12        80.0       missing
# 9          109   Robert Brown   17  female    12         NaN       missing
# 10         110      lucy gray   17    male  11th        65.0            67
# 11         111   Simran Singh   16  female  11th         NaN       missing
# 12         112       Patel R.   17  female    11         NaN            87
# 13         113       Patel R.   17    male    10         NaN           NaN
# 14         114       Ali Khan   17    male    12         NaN            91
# 15         115      Lucy gray   16  female    12        65.0            91
# 16         116       Chris P.   16  female    11         NaN           NaN
# 17         117       Ali Khan   18    male  11th        67.0            74
# 18         118   Simran Singh   17    male    10       100.0            74
# 19         119       Patel R.   17    male  11th        73.0           NaN
# 20         120    Sara O'Neil   17    male    10         NaN       missing
# 21         121       John Doe   18  female    11        66.0            72
# 22         122    Sara O'Neil   17    male  11th        75.0           NaN
# 23         123     jane smith   17  female  11th         NaN       missing
# 24         124       John Doe   18    male  11th         NaN           NaN
# 25         125  Mike O’Reilly   17    male    12        94.0            80
# 26         126       John Doe   16    male  10th        64.0       missing
# 27         127   Simran Singh   16  female    12         NaN            76
# 28         128    Sara O'Neil   17  female    11         NaN            64
# 29         129       Patel R.   17    male    11         NaN            64
#
#     science_score enrolled_date            remarks
# 0              66    2022-06-10          excellent
# 1              94    2022-06-10               GOOD
# 2              69    2022-12-06  needs improvement
# 3              62    2022-06-10            average
# 4              64    2022-06-10               GOOD
# 5              83    2022-12-06  needs improvement
# 6              75    2022-12-06               Good
# 7              62    2022-06-11          excellent
# 8              89    2022-12-06               poor
# 9              97    2022-06-10  needs improvement
# 10            100    2022-12-06          excellent
# 11             95    2022-06-10            average
# 12             89    2022-06-10               poor
# 13             98    2022-12-06            Average
# 14             67    2022-06-11               poor
# 15             94    2022-12-06            Average
# 16             72    2022-06-11          excellent
# 17             81    2022-06-10               GOOD
# 18             62    2022-06-11            average
# 19             90    2022-12-06               Good
# 20             89    2022-06-10            average
# 21             94    2022-06-10            Average
# 22             66    2022-06-10       good student
# 23             63    2022-12-06          excellent
# 24             91    2022-12-06               GOOD
# 25             63    2022-06-10            Average
# 26             67    2022-12-06       good student
# 27             80    2022-12-06               poor
# 28             89    2022-06-10            average
# 29             83    2022-06-11            Average

# %% [markdown]
# **Rename Columns**
#
#    Rename columns to be clear, consistent, and Python-friendly (e.g., no spaces,
# lowercase).

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %% [markdown]
# **Final Clean Dataset**
#
#   Display the cleaned dataset.
#
#   Save the cleaned dataset to a new CSV file.

# %%
df.head()
# Out:
#    student_id         name  age  gender grade  math_score english_score  \
# 0         100   jane smith   16  female    11        75.0           NaN
# 1         101     John Doe   16    male  10th        74.0            95
# 2         102     Chris P.   16    male    10         NaN       missing
# 3         103   jane smith   16  female    10         NaN       missing
# 4         104  Sara O'Neil   16    male    11         NaN            96
#
#    science_score enrolled_date            remarks
# 0             66    2022-06-10          excellent
# 1             94    2022-06-10               GOOD
# 2             69    2022-12-06  needs improvement
# 3             62    2022-06-10            average
# 4             64    2022-06-10               GOOD

# %%
df.to_csv("students_data_cleaned.csv", index=False)

# %% [markdown]
# **Conclusion**
#
# Missing values were handled appropriately.
#
# Duplicate records were removed.
#
# Data types were corrected.
#
# Text data was standardized.
#
# Column names were renamed for clarity.
#
# The final dataset is clean, consistent, and analysis-ready.
